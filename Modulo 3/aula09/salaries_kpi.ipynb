# %%
import pandas as pd

df = pd.read_csv('Salaries.csv')

display(df.columns)
# Out:
# Index(['Id', 'EmployeeName', 'JobTitle', 'BasePay', 'OvertimePay', 'OtherPay',
#        'Benefits', 'TotalPay', 'TotalPayBenefits', 'Year', 'Notes', 'Agency',
#        'Status'],
#       dtype='str')

# %%
for colunas in df.columns:
    print(colunas)
# Out:
# Id
# EmployeeName
# JobTitle
# BasePay
# OvertimePay
# OtherPay
# Benefits
# TotalPay
# TotalPayBenefits
# Year
# Notes
# Agency
# Status

# %%
df = df.rename(columns={
    "Id": "Identificador",
    "EmployeeName": "NomeDoFuncionario",
    "JobTitle": "Cargo",
    "BasePay": "SalarioBase",
    "OvertimePay": "PagamentoHorasExtras",
    "OtherPay": "OutrosPagamentos",
    "Benefits": "Beneficios",
    "TotalPay": "PagamentoTotal",
    "TotalPayBenefits": "TotalPagamentoEBeneficios",
    "Year": "Ano",
    "Notes": "Notas",
    "Agency": "Agencia",
    "Status": "Status"
})

for colunas in df.columns:
    print(colunas)
# Out:
# Identificador
# NomeDoFuncionario
# Cargo
# SalarioBase
# PagamentoHorasExtras
# OutrosPagamentos
# Beneficios
# PagamentoTotal
# TotalPagamentoEBeneficios
# Ano
# Notas
# Agencia
# Status

# %%
# Qual período, quais anos foram coletados?
#anos = df['Ano'].unique()
#print(anos)

# Quantos e quais cargos foram registrados?
#cargos = sorted(df['Cargo'].unique())
#for i in cargos:
#    print(i)

# Qual a média de salários pagos ordenado do maior para o menor?
#salario = df.groupby('Cargo')['TotalPagamentoEBeneficios'].mean().sort_values(ascending=False).head(10)
#print(salario)

# Qual o funcionário mais bem pago da lista?
#maisPago = df.groupby('NomeDoFuncionario')['TotalPagamentoEBeneficios'].mean().sort_values(ascending=False).head(1)
#print(maisPago)

# Quantos funcionários tem em cada cargo?
qtdeFunc = df['Cargo'].value_counts()

qtdeFunc.to_csv('relatório_cargos.csv')
print('relatório gerado com sucesso')
# Out:
# relatório gerado com sucesso
