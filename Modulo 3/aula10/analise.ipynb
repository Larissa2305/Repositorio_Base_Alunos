# %%
import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_csv('Compras.csv', sep=';')
display(df.head())
# Out:
#    CódigoCompra        Data               Fornecedor  \
# 0         65014  01/12/2023   Fabrica Hashtag Brasil
# 1         65014  01/12/2023   Fabrica Hashtag Brasil
# 2         65016  01/12/2023   Fabrica Doidona Brasil
# 3         65016  01/12/2023   Fabrica Doidona Brasil
# 4         65017  01/12/2023  Original Fábrica Brasil
#
#                      Produto  Quantidade  ValorUnitário  ValorFinal
# 0       Óleo Motor - Linha A           5          259.0      1295.0
# 1    Kit Embreagem - Linha A           1          380.0       380.0
# 2          Bateria - Linha A           2          479.0       958.0
# 3   Filtro de Óleo - Linha A           1           18.9        18.9
# 4  Farol Principal - Linha A           3          159.9       479.7

# %%
for colunas in df.columns:
    print(colunas)
# Out:
# CódigoCompra
# Data
# Fornecedor
# Produto
# Quantidade
# ValorUnitário
# ValorFinal

# %%
# Qual o produto mais vendido?
maisVendido = round(df.groupby('Produto')['Quantidade'].sum().sort_values(ascending=False).head(1))
print(maisVendido)
# Out:
# Produto
# Filtro Combustível - Linha Premium    163
# Name: Quantidade, dtype: int64

# %%
# Relacione as vendas por fornecedor.
vendForn = df.groupby('Fornecedor')['ValorUnitário'].sum().sort_index()
print(vendForn)
# Out:
# Fornecedor
# Fabrica Doidona Argentina         84310.71
# Fabrica Doidona Asia             178888.33
# Fabrica Doidona Brasil           190331.49
# Fabrica Doidona EUA              100584.30
# Fabrica Doidona Europa           136624.59
# Fabrica Doidona Mexico           127354.94
# Fabrica Hashtag Argentina        135777.43
# Fabrica Hashtag Asia             116411.42
# Fabrica Hashtag Brasil           124455.85
# Fabrica Hashtag EUA              152837.27
# Fabrica Hashtag Europa           146372.12
# Fabrica Hashtag Internacional    130867.18
# Fabrica Hashtag Mexico           182857.53
# Original Fábrica Argentina       115564.92
# Original Fábrica Asia            154499.26
# Original Fábrica Brasil          128559.98
# Original Fábrica EUA             148580.59
# Original Fábrica Europa          144674.60
# Original Fábrica Mexico          113321.55
# Revenda Argentina                151150.10
# Revenda Asia                      97718.20
# ...

# %%
# Data que os produtos foram mais vendidos.
data = round(df.groupby('Data')['Quantidade'].sum().sort_values(ascending=False).head(1))
print(data)
# Out:
# Data
# 01/12/2023    485
# Name: Quantidade, dtype: int64

# %%
df['Regiao'] = df['Fornecedor'].str.split().str[-1]
display(df.head(20))
# Out:
#     CódigoCompra        Data               Fornecedor  \
# 0          65014  01/12/2023   Fabrica Hashtag Brasil
# 1          65014  01/12/2023   Fabrica Hashtag Brasil
# 2          65016  01/12/2023   Fabrica Doidona Brasil
# 3          65016  01/12/2023   Fabrica Doidona Brasil
# 4          65017  01/12/2023  Original Fábrica Brasil
# 5          65018  01/12/2023           Revenda Brasil
# 6          65018  01/12/2023           Revenda Brasil
# 7          65018  01/12/2023           Revenda Brasil
# 8          65019  01/12/2023   Fabrica Hashtag Europa
# 9          65019  01/12/2023   Fabrica Hashtag Europa
# 10         65020  01/12/2023   Fabrica Hashtag Brasil
# 11         65020  01/12/2023   Fabrica Hashtag Brasil
# 12         65020  01/12/2023   Fabrica Hashtag Brasil
# 13         65024  01/12/2023   Fabrica Doidona Europa
# 14         65025  01/12/2023  Original Fábrica Europa
# 15         65025  01/12/2023  Original Fábrica Europa
# ...

# %%
top5_produtos = df.groupby('Produto')['Quantidade'].sum().sort_values(ascending=False).head(5)
print(top5_produtos)
# Out:
# Produto
# Filtro Combustível - Linha Premium    163
# Bomba d'agua - Linha A                159
# Filtro Combustível - Linha B          158
# Correia - Linha A                     157
# Terminal de Direção - Linha C         157
# Name: Quantidade, dtype: int64

# %%
maisCaro = df.loc[df['ValorFinal'].idxmax()]
print(maisCaro)
# Out:
# CódigoCompra                               65793
# Data                                  05/12/2023
# Fornecedor                Fabrica Hashtag Europa
# Produto          Caixa de Marcha - Linha Premium
# Quantidade                                     5
# ValorUnitário                           11218.77
# ValorFinal                              56093.84
# Regiao                                    Europa
# Name: 782, dtype: object

# %%
top1Fornecedor = df.groupby('Fornecedor')['Quantidade'].sum().idxmax()
print(f'O fornecedor que mais vendeu foi {top1Fornecedor}')
# Out:
# O fornecedor que mais vendeu foi Revenda EUA

# %%
df['Data'] = pd.to_datetime(df['Data'], format='%d/%m/%Y')
print(df.info())
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 4543 entries, 0 to 4542
# Data columns (total 8 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   CódigoCompra   4543 non-null   int64
#  1   Data           4543 non-null   datetime64[us]
#  2   Fornecedor     4543 non-null   str
#  3   Produto        4543 non-null   str
#  4   Quantidade     4543 non-null   int64
#  5   ValorUnitário  4543 non-null   float64
#  6   ValorFinal     4543 non-null   float64
#  7   Regiao         4543 non-null   object
# dtypes: datetime64[us](1), float64(2), int64(2), object(1), str(2)
# memory usage: 284.1+ KB
# None

# %%
faturamento_total = df['ValorFinal'].sum()
print(f'Faturamento total: R$ {faturamento_total:.2f} reais')
# Out:
# Faturamento total: R$ 7254196.58 reais
